# %%
from vllm import LLM, SamplingParams
model_name = "/mnt/petrelfs/songmingyang/songmingyang/model/tool-augment/Qwen2-VL-7B-Instruct"
model_name = "/mnt/petrelfs/songmingyang/quxiaoye/models/Qwen2-VL-72B-Instruct"
model = LLM(model_name)
# Out:
# INFO 01-21 22:05:37 config.py:350] This model supports multiple tasks: {'embedding', 'generate'}. Defaulting to 'generate'.
# ...
